# %% [markdown]
# ### Machine learning model for detection of anemia through Images

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import cv2

# %%
df= pd.read_csv('C:/Users/BHAVIT JAIN/Desktop/datasetmajor.csv')
df.head()
# Out:
#    Patient_Number                       IMAGES  Result  Origional
# 0               1  Cropped_Image_Patient_1.png       1          1
# 1               2  Cropped_Image_Patient_2.png       1          1
# 2               3  Cropped_Image_Patient_3.png       0          0
# 3               4  Cropped_Image_Patient_4.png       1          1
# 4               5  Cropped_Image_Patient_5.png       1          1

# %%
for i in range(5):
    img = cv2.imread(df.IMAGES[i])
    img.shape
    plt.matshow(img) 
    plt.imshow(img)

# %%
img
# Out:
# array([[[ 19,  34,  53],
#         [ 20,  35,  54],
#         [ 22,  37,  56],
#         ...,
#         [ 22,  33,  63],
#         [ 23,  34,  64],
#         [ 23,  34,  64]],
#
#        [[ 24,  39,  58],
#         [ 25,  40,  59],
#         [ 27,  42,  61],
#         ...,
#         [ 21,  32,  62],
#         [ 22,  33,  63],
#         [ 23,  34,  64]],
#
#        [[ 29,  44,  63],
#         [ 30,  45,  64],
#         [ 31,  46,  65],
#         ...,
#         [ 18,  32,  61],
#         [ 21,  32,  64],
#         [ 21,  32,  64]],
#
#        ...,
#
#        [[136, 151, 183],
#         [134, 149, 181],
#         [134, 146, 180],
#         ...,
#         [149, 160, 192],
#         [151, 162, 194],
#         [152, 163, 195]],
#
#        [[137, 152, 184],
#         [135, 150, 182],
#         [134, 146, 180],
#         ...,
#         [151, 162, 194],
#         [152, 163, 195],
#         [153, 164, 196]],
#
#        [[137, 152, 184],
#         [136, 151, 183],
#         [134, 149, 181],
# ...

# %%
vector = np.vectorize(np.float)
l=[]
for i in range(16):
    img = cv2.imread(df.IMAGES[i])
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY).ravel()
    l.append(vector(gray))
print(l)
# Out:
# [array([163., 162., 162., ..., 206., 206., 205.]), array([ 97.,  90.,  89., ..., 130., 130., 129.]), array([168., 166., 165., ..., 208., 204., 204.]), array([54., 55., 60., ..., 91., 96., 95.]), array([ 38.,  39.,  41., ..., 171., 172., 172.]), array([ 60.,  71.,  91., ..., 113.,  93.,  94.]), array([ 85.,  91.,  92., ..., 156., 157., 148.]), array([170., 171., 171., ..., 196., 197., 198.]), array([ 77.,  73.,  64., ..., 108., 111., 107.]), array([ 93.,  89.,  88., ..., 132., 146., 146.]), array([191., 195., 196., ..., 162., 176., 185.]), array([213., 212., 214., ..., 118., 123., 118.]), array([ 59.,  58.,  62., ..., 165., 167., 169.]), array([187., 188., 186., ..., 222., 213., 207.]), array([ 64.,  62.,  60., ..., 133., 135., 136.]), array([100.,  99.,  97., ..., 114., 118., 121.])]

# %%
df['Images_arr']= l
df
# Out:
#     Patient_Number                        IMAGES  Result  Origional  \
# 0                1   Cropped_Image_Patient_1.png       1          1
# 1                2   Cropped_Image_Patient_2.png       1          1
# 2                3   Cropped_Image_Patient_3.png       0          0
# 3                4   Cropped_Image_Patient_4.png       1          1
# 4                5   Cropped_Image_Patient_5.png       1          1
# 5                6   Cropped_Image_Patient_6.png       0          1
# 6                7   Cropped_Image_Patient_7.png       0          0
# 7                8   Cropped_Image_Patient_8.png       1          1
# 8                9   Cropped_Image_Patient_9.png       1          0
# 9               10  Cropped_Image_Patient_10.png       1          1
# 10              11  Cropped_Image_Patient_11.png       0          0
# 11              12  Cropped_Image_Patient_12.png       1          1
# 12              13  Cropped_Image_Patient_13.png       1          1
# ...

# %%
a=df.Images_arr[0]
a
# Out:
# array([163., 162., 162., ..., 206., 206., 205.])

# %%
l1=[]
for j in df.Images_arr:
    l1.append(list(j))

# %%
Images_arr_new=np.array(l1)
Images_arr_new
# Out:
# array([[163., 162., 162., ..., 206., 206., 205.],
#        [ 97.,  90.,  89., ..., 130., 130., 129.],
#        [168., 166., 165., ..., 208., 204., 204.],
#        ...,
#        [187., 188., 186., ..., 222., 213., 207.],
#        [ 64.,  62.,  60., ..., 133., 135., 136.],
#        [100.,  99.,  97., ..., 114., 118., 121.]])

# %%
Images_arr_new.shape
# Out:
# (16, 50176)

# %%
df.Origional.shape
# Out:
# (16,)

# %%
l2=[]

for k in df.Origional:
    l2.append([k])

# %%
new_origional = np.array(l2)
new_origional.shape
# Out:
# (16, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(Images_arr_new,new_origional, test_size=0.3)

# %%
len(X_train)
# Out:
# 11

# %%
len(X_test)
# Out:
# 5

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# C:\Users\BHAVIT JAIN\ANACONDA\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# LogisticRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.8

# %%
y_prid = model.predict(X_test)
y_prid
# Out:
# array([1, 1, 0, 1, 1])

# %%
y_test
# Out:
# array([[1],
#        [1],
#        [1],
#        [1],
#        [1]])

# %%
X_test
# Out:
# array([[ 59.,  58.,  62., ..., 165., 167., 169.],
#        [163., 162., 162., ..., 206., 206., 205.],
#        [170., 171., 171., ..., 196., 197., 198.],
#        [ 97.,  90.,  89., ..., 130., 130., 129.],
#        [ 54.,  55.,  60., ...,  91.,  96.,  95.]])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_prid)
cm
# Out:
# array([[0, 0],
#        [1, 4]], dtype=int64)

# %%
import seaborn as sns
plt.figure(figsize = (10,10))
sns.heatmap(cm,annot = True)
plt.xlabel('predicted')
plt.ylabel('original')
# Out:
# Text(69.0, 0.5, 'original')

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
pipe= Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel='rbf', C=10))])
pipe.fit(X_train,y_train)
# Out:
# C:\Users\BHAVIT JAIN\ANACONDA\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Pipeline(steps=[('scaler', StandardScaler()), ('svc', SVC(C=10))])

# %%
pipe.score(X_test,y_test)
# Out:
# 0.8

# %% [markdown]
# ##  Predicting different images those are not in train or test data.

# %%
img = cv2.imread('Cropped_Image_Patient_18.png')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY).ravel()
a=list(vector(gray))
b=np.array([a])
print(b)
b.shape
# Out:
# [[152. 150. 147. ... 183. 181. 180.]]
# (1, 50176)

# %%
model.predict(b)
# Out:
# array([1])

# %%
pipe.predict(b)
# Out:
# array([1])

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=3, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# C:\Users\BHAVIT JAIN\ANACONDA\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\BHAVIT JAIN\ANACONDA\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\BHAVIT JAIN\ANACONDA\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc', SVC(C=1, gamma='auto', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=5))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.8

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.6

# %%
best_clf = best_estimators['svm']

# %%
cm1 = confusion_matrix(y_test, best_clf.predict(X_test))
cm1
# Out:
# array([[0, 0],
#        [1, 4]], dtype=int64)

# %%
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %% [markdown]
# ## save the trained model

# %%
import joblib 
# Saving the model as a pickle in a file 
joblib.dump(best_clf, 'anemia_detection_model.pkl')
# Out:
# ['anemia_detection_model.pkl']

# %%
sm= joblib.load('anemia_detection_model.pkl')

# %%
sm.predict([Images_arr_new[3]])
# Out:
# array([1])

# %%
sm.predict([Images_arr_new[10]])
# Out:
# array([0])
